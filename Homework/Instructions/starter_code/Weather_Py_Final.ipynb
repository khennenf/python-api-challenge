# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import pprint
import json

# # Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Check API Key
from api_keys import weather_api_key
print(weather_api_key)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-8aff001e18f8> in <module>
#       1 #Check API Key
# ----> 2 from api_keys import weather_api_key
#       3 print(weather_api_key)
#
# ImportError: cannot import name 'weather_api_key' from 'api_keys' (C:\Users\keri.ROGUE\Desktop\python-api-challenge\Homework\Instructions\starter_code\api_keys.py)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=2000)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %%
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
weather_response = requests.get(query_url)
weather_json = weather_response.json() 
print (f"The Weather is {weather_json}")
print(query_url)
# Out:
# The Weather is {'cod': '400', 'message': 'Nothing to geocode'}
# http://api.openweathermap.org/data/2.5/weather?appid=97afa3557763951911324b72372185fa&units=imperial&q=

# %%
lat = []
lon = []
max_temp = []
clouds = []
wind = []
humidity = []
country=[]
city_name=[]
last_update=[]

# %%
def  consecutive_numbers(n) :
    list=[i for i in range(len(cities))]
    return (list)
print(consecutive_numbers)

# %%
print(f"Beginning Data Retrieval \n___________________________")
for city in cities:
    try:
        weather_response = requests.get(query_url + city)
        text_response = weather_response.json()
        lat.append(text_response['coord']['lat'])
        lon.append(text_response['coord']['lon'])
        max_temp.append(text_response['main']['temp_max'])
        clouds.append(text_response['clouds']['all'])
        humidity.append(text_response['main']['humidity'])
        wind.append(text_response['wind']['speed'])
        country.append(text_response['sys']['country'])
        city_name.append(text_response['name'])
        print(f"Processing Record {len(city_name)} of Set 1 | {city}")
                   
    except KeyError:
        print(f"We can't find {city}")
# Out:
# Beginning Data Retrieval
# ___________________________
# Processing Record 1 of Set 1 | savonlinna
# Processing Record 2 of Set 1 | codrington
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | san cristobal
# Processing Record 5 of Set 1 | guerrero negro
# Processing Record 6 of Set 1 | coquimbo
# Processing Record 7 of Set 1 | tuatapere
# Processing Record 8 of Set 1 | bredasdorp
# We can't find mys shmidta
# Processing Record 9 of Set 1 | goderich
# We can't find kerteh
# Processing Record 10 of Set 1 | sao filipe
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | richmond
# Processing Record 13 of Set 1 | thinadhoo
# Processing Record 14 of Set 1 | shimoda
# Processing Record 15 of Set 1 | saint-augustin
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | saint-philippe
# We can't find umzimvubu
# Processing Record 18 of Set 1 | cabatuan
# Processing Record 19 of Set 1 | kalmunai
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | kaberamaido
# We can't find dzhusaly
# Processing Record 24 of Set 1 | baruun-urt
# Processing Record 25 of Set 1 | grindavik
# Processing Record 26 of Set 1 | saint george
# Processing Record 27 of Set 1 | alice springs
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | valparaiso
# Processing Record 30 of Set 1 | kirakira
# We can't find tsihombe
# Processing Record 31 of Set 1 | san quintin
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | nuuk
# Processing Record 34 of Set 1 | samarai
# Processing Record 35 of Set 1 | macenta
# Processing Record 36 of Set 1 | victoria
# Processing Record 37 of Set 1 | coihaique
# Processing Record 38 of Set 1 | tilichiki
# Processing Record 39 of Set 1 | kiomboi
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | ushuaia
# We can't find ji-parana
# Processing Record 42 of Set 1 | santa cruz
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | punta arenas
# We can't find amderma
# We can't find grand river south east
# Processing Record 45 of Set 1 | flinders
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | adrar
# Processing Record 48 of Set 1 | olafsvik
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | caravelas
# Processing Record 51 of Set 1 | carnarvon
# Processing Record 52 of Set 1 | ola
# Processing Record 53 of Set 1 | ostrovnoy
# We can't find wazzan
# Processing Record 54 of Set 1 | chuy
# Processing Record 55 of Set 1 | pangnirtung
# Processing Record 56 of Set 1 | lorengau
# We can't find taolanaro
# Processing Record 57 of Set 1 | jamestown
# Processing Record 58 of Set 1 | salalah
# Processing Record 59 of Set 1 | rio grande
# Processing Record 60 of Set 1 | kashiwazaki
# Processing Record 61 of Set 1 | cape town
# Processing Record 62 of Set 1 | gorontalo
# We can't find saleaula
# Processing Record 63 of Set 1 | bandar
# Processing Record 64 of Set 1 | khandyga
# Processing Record 65 of Set 1 | akyab
# Processing Record 66 of Set 1 | butaritari
# Processing Record 67 of Set 1 | kyabram
# Processing Record 68 of Set 1 | qaanaaq
# Processing Record 69 of Set 1 | umba
# Processing Record 70 of Set 1 | hermanus
# Processing Record 71 of Set 1 | shar
# Processing Record 72 of Set 1 | jardim
# Processing Record 73 of Set 1 | kodiak
# Processing Record 74 of Set 1 | hobart
# Processing Record 75 of Set 1 | shingu
# Processing Record 76 of Set 1 | acarau
# Processing Record 77 of Set 1 | bonavista
# Processing Record 78 of Set 1 | sitka
# Processing Record 79 of Set 1 | lasa
# Processing Record 80 of Set 1 | richards bay
# Processing Record 81 of Set 1 | kandrian
# Processing Record 82 of Set 1 | port alfred
# Processing Record 83 of Set 1 | pisco
# Processing Record 84 of Set 1 | karratha
# Processing Record 85 of Set 1 | georgetown
# Processing Record 86 of Set 1 | kariba
# We can't find illoqqortoormiut
# Processing Record 87 of Set 1 | dingle
# We can't find vastervik
# Processing Record 88 of Set 1 | kruisfontein
# Processing Record 89 of Set 1 | hilo
# We can't find gulshat
# Processing Record 90 of Set 1 | sechura
# Processing Record 91 of Set 1 | busselton
# Processing Record 92 of Set 1 | cherskiy
# Processing Record 93 of Set 1 | oktyabrskoye
# Processing Record 94 of Set 1 | nome
# We can't find sindand
# Processing Record 95 of Set 1 | znamenskoye
# Processing Record 96 of Set 1 | general roca
# Processing Record 97 of Set 1 | bluff
# Processing Record 98 of Set 1 | umm lajj
# Processing Record 99 of Set 1 | lebu
# Processing Record 100 of Set 1 | winslow
# Processing Record 101 of Set 1 | marzuq
# Processing Record 102 of Set 1 | norman wells
# Processing Record 103 of Set 1 | souillac
# Processing Record 104 of Set 1 | mbini
# Processing Record 105 of Set 1 | hambantota
# Processing Record 106 of Set 1 | narsaq
# Processing Record 107 of Set 1 | mahebourg
# Processing Record 108 of Set 1 | port elizabeth
# We can't find barentsburg
# Processing Record 109 of Set 1 | longyearbyen
# Processing Record 110 of Set 1 | tigil
# Processing Record 111 of Set 1 | labuan
# Processing Record 112 of Set 1 | koumra
# Processing Record 113 of Set 1 | kapaa
# Processing Record 114 of Set 1 | bethel
# Processing Record 115 of Set 1 | kavaratti
# Processing Record 116 of Set 1 | brive-la-gaillarde
# Processing Record 117 of Set 1 | kangasala
# Processing Record 118 of Set 1 | arraial do cabo
# Processing Record 119 of Set 1 | whitehorse
# We can't find buqayq
# Processing Record 120 of Set 1 | quatre cocos
# Processing Record 121 of Set 1 | wanning
# We can't find belushya guba
# Processing Record 122 of Set 1 | kawai
# Processing Record 123 of Set 1 | pevek
# Processing Record 124 of Set 1 | hamilton
# Processing Record 125 of Set 1 | san carlos de bariloche
# Processing Record 126 of Set 1 | surt
# Processing Record 127 of Set 1 | fortuna
# Processing Record 128 of Set 1 | cabo san lucas
# Processing Record 129 of Set 1 | kaitangata
# Processing Record 130 of Set 1 | saskylakh
# Processing Record 131 of Set 1 | saldanha
# Processing Record 132 of Set 1 | lockhart
# Processing Record 133 of Set 1 | komsomolskiy
# Processing Record 134 of Set 1 | albany
# Processing Record 135 of Set 1 | jumla
# Processing Record 136 of Set 1 | paamiut
# Processing Record 137 of Set 1 | constitucion
# Processing Record 138 of Set 1 | mitsamiouli
# Processing Record 139 of Set 1 | moorhead
# Processing Record 140 of Set 1 | flin flon
# Processing Record 141 of Set 1 | udachnyy
# Processing Record 142 of Set 1 | vaini
# Processing Record 143 of Set 1 | sola
# Processing Record 144 of Set 1 | abnub
# Processing Record 145 of Set 1 | san luis
# Processing Record 146 of Set 1 | vestmannaeyjar
# Processing Record 147 of Set 1 | pimentel
# Processing Record 148 of Set 1 | dikson
# Processing Record 149 of Set 1 | moose factory
# Processing Record 150 of Set 1 | torbay
# Processing Record 151 of Set 1 | sorong
# We can't find halalo
# Processing Record 152 of Set 1 | aykhal
# Processing Record 153 of Set 1 | amapa
# We can't find milingimbi
# Processing Record 154 of Set 1 | talaya
# Processing Record 155 of Set 1 | ukiah
# Processing Record 156 of Set 1 | bexbach
# Processing Record 157 of Set 1 | salamiyah
# Processing Record 158 of Set 1 | nanortalik
# Processing Record 159 of Set 1 | atherton
# Processing Record 160 of Set 1 | north bend
# Processing Record 161 of Set 1 | isangel
# Processing Record 162 of Set 1 | cayenne
# Processing Record 163 of Set 1 | mackenzie
# Processing Record 164 of Set 1 | edd
# Processing Record 165 of Set 1 | la ronge
# Processing Record 166 of Set 1 | los llanos de aridane
# Processing Record 167 of Set 1 | port blair
# Processing Record 168 of Set 1 | mazzarino
# Processing Record 169 of Set 1 | makueni
# Processing Record 170 of Set 1 | khatanga
# We can't find sentyabrskiy
# Processing Record 171 of Set 1 | shamkhal
# Processing Record 172 of Set 1 | chany
# Processing Record 173 of Set 1 | dahuk
# Processing Record 174 of Set 1 | rondonopolis
# Processing Record 175 of Set 1 | ganzhou
# We can't find hihifo
# Processing Record 176 of Set 1 | marawi
# Processing Record 177 of Set 1 | mareeba
# Processing Record 178 of Set 1 | hithadhoo
# Processing Record 179 of Set 1 | pitanga
# Processing Record 180 of Set 1 | hualmay
# Processing Record 181 of Set 1 | great falls
# Processing Record 182 of Set 1 | yulara
# Processing Record 183 of Set 1 | gat
# Processing Record 184 of Set 1 | alofi
# Processing Record 185 of Set 1 | sabha
# Processing Record 186 of Set 1 | provideniya
# Processing Record 187 of Set 1 | nanning
# Processing Record 188 of Set 1 | thompson
# Processing Record 189 of Set 1 | namibe
# Processing Record 190 of Set 1 | mar del plata
# Processing Record 191 of Set 1 | oranjemund
# Processing Record 192 of Set 1 | hasaki
# Processing Record 193 of Set 1 | esperance
# Processing Record 194 of Set 1 | maneadero
# We can't find samalaeulu
# Processing Record 195 of Set 1 | east london
# Processing Record 196 of Set 1 | liku
# Processing Record 197 of Set 1 | nizhneivkino
# Processing Record 198 of Set 1 | college
# Processing Record 199 of Set 1 | atuona
# Processing Record 200 of Set 1 | curaca
# Processing Record 201 of Set 1 | lagoa
# Processing Record 202 of Set 1 | marinette
# Processing Record 203 of Set 1 | san ramon
# Processing Record 204 of Set 1 | puerto del rosario
# Processing Record 205 of Set 1 | itamaraju
# Processing Record 206 of Set 1 | tari
# Processing Record 207 of Set 1 | sisimiut
# Processing Record 208 of Set 1 | coracora
# Processing Record 209 of Set 1 | klaksvik
# Processing Record 210 of Set 1 | mujiayingzi
# Processing Record 211 of Set 1 | shelburne
# Processing Record 212 of Set 1 | kavieng
# Processing Record 213 of Set 1 | prosvet
# Processing Record 214 of Set 1 | imbituba
# Processing Record 215 of Set 1 | mount isa
# Processing Record 216 of Set 1 | padang
# Processing Record 217 of Set 1 | iaciara
# Processing Record 218 of Set 1 | tessalit
# Processing Record 219 of Set 1 | ruwi
# Processing Record 220 of Set 1 | tonekabon
# Processing Record 221 of Set 1 | tarko-sale
# Processing Record 222 of Set 1 | lawton
# Processing Record 223 of Set 1 | carmen
# We can't find burica
# Processing Record 224 of Set 1 | asau
# Processing Record 225 of Set 1 | never
# Processing Record 226 of Set 1 | pathein
# We can't find tumannyy
# Processing Record 227 of Set 1 | geraldton
# Processing Record 228 of Set 1 | itarema
# Processing Record 229 of Set 1 | hami
# Processing Record 230 of Set 1 | airai
# Processing Record 231 of Set 1 | vikulovo
# We can't find attawapiskat
# Processing Record 232 of Set 1 | saint cloud
# Processing Record 233 of Set 1 | nhulunbuy
# We can't find alotau
# Processing Record 234 of Set 1 | ilulissat
# Processing Record 235 of Set 1 | businga
# Processing Record 236 of Set 1 | panaba
# Processing Record 237 of Set 1 | reconquista
# Processing Record 238 of Set 1 | fort nelson
# Processing Record 239 of Set 1 | yaan
# Processing Record 240 of Set 1 | jamui
# Processing Record 241 of Set 1 | henties bay
# Processing Record 242 of Set 1 | zhigansk
# Processing Record 243 of Set 1 | adana
# Processing Record 244 of Set 1 | gerash
# We can't find nizhneyansk
# Processing Record 245 of Set 1 | marana
# We can't find tarhunah
# Processing Record 246 of Set 1 | faanui
# Processing Record 247 of Set 1 | charleston
# Processing Record 248 of Set 1 | raymond
# Processing Record 249 of Set 1 | dwarka
# Processing Record 250 of Set 1 | marsa matruh
# Processing Record 251 of Set 1 | dunedin
# Processing Record 252 of Set 1 | berberati
# Processing Record 253 of Set 1 | bintulu
# Processing Record 254 of Set 1 | ongandjera
# Processing Record 255 of Set 1 | makakilo city
# Processing Record 256 of Set 1 | vao
# Processing Record 257 of Set 1 | severo-kurilsk
# Processing Record 258 of Set 1 | birao
# Processing Record 259 of Set 1 | san isidro
# Processing Record 260 of Set 1 | santa cruz cabralia
# We can't find kegayli
# Processing Record 261 of Set 1 | upernavik
# Processing Record 262 of Set 1 | pato branco
# Processing Record 263 of Set 1 | soma
# Processing Record 264 of Set 1 | kichera
# Processing Record 265 of Set 1 | zheleznodorozhnyy
# Processing Record 266 of Set 1 | buala
# Processing Record 267 of Set 1 | janakkala
# Processing Record 268 of Set 1 | iqaluit
# Processing Record 269 of Set 1 | avera
# Processing Record 270 of Set 1 | namatanai
# Processing Record 271 of Set 1 | tual
# Processing Record 272 of Set 1 | tasiilaq
# Processing Record 273 of Set 1 | chokurdakh
# Processing Record 274 of Set 1 | vangaindrano
# Processing Record 275 of Set 1 | cabra
# Processing Record 276 of Set 1 | boulder city
# Processing Record 277 of Set 1 | lata
# Processing Record 278 of Set 1 | trowbridge
# Processing Record 279 of Set 1 | sortavala
# Processing Record 280 of Set 1 | kalanwali
# Processing Record 281 of Set 1 | suez
# Processing Record 282 of Set 1 | saint-orens-de-gameville
# We can't find gazni
# Processing Record 283 of Set 1 | clyde river
# Processing Record 284 of Set 1 | kloulklubed
# Processing Record 285 of Set 1 | luderitz
# Processing Record 286 of Set 1 | setermoen
# Processing Record 287 of Set 1 | tyukhtet
# Processing Record 288 of Set 1 | malchevskaya
# We can't find kracheh
# Processing Record 289 of Set 1 | ormara
# Processing Record 290 of Set 1 | chebenki
# Processing Record 291 of Set 1 | bengkulu
# Processing Record 292 of Set 1 | bud
# Processing Record 293 of Set 1 | shieli
# Processing Record 294 of Set 1 | san patricio
# Processing Record 295 of Set 1 | raudeberg
# Processing Record 296 of Set 1 | vostok
# Processing Record 297 of Set 1 | san jose
# We can't find palabuhanratu
# Processing Record 298 of Set 1 | naryan-mar
# Processing Record 299 of Set 1 | labuhan
# Processing Record 300 of Set 1 | zhanaozen
# Processing Record 301 of Set 1 | fort-shevchenko
# Processing Record 302 of Set 1 | amol
# Processing Record 303 of Set 1 | port lincoln
# Processing Record 304 of Set 1 | malanje
# Processing Record 305 of Set 1 | kathmandu
# Processing Record 306 of Set 1 | waimana
# Processing Record 307 of Set 1 | poum
# Processing Record 308 of Set 1 | beloha
# Processing Record 309 of Set 1 | zatoka
# Processing Record 310 of Set 1 | nouadhibou
# Processing Record 311 of Set 1 | sibolga
# Processing Record 312 of Set 1 | jambi
# We can't find macaboboni
# Processing Record 313 of Set 1 | egvekinot
# Processing Record 314 of Set 1 | atasu
# Processing Record 315 of Set 1 | goure
# Processing Record 316 of Set 1 | todos santos
# We can't find lolua
# Processing Record 317 of Set 1 | meghri
# Processing Record 318 of Set 1 | ixtapa
# Processing Record 319 of Set 1 | guarapari
# Processing Record 320 of Set 1 | bambous virieux
# Processing Record 321 of Set 1 | diplo
# Processing Record 322 of Set 1 | bordighera
# Processing Record 323 of Set 1 | broome
# Processing Record 324 of Set 1 | sukumo
# Processing Record 325 of Set 1 | bac lieu
# Processing Record 326 of Set 1 | bilibino
# Processing Record 327 of Set 1 | ygatimi
# We can't find zolotinka
# We can't find ituni
# Processing Record 328 of Set 1 | belebey
# Processing Record 329 of Set 1 | banamba
# Processing Record 330 of Set 1 | ashti
# Processing Record 331 of Set 1 | trincomalee
# Processing Record 332 of Set 1 | kolondieba
# Processing Record 333 of Set 1 | portland
# Processing Record 334 of Set 1 | solnechnyy
# Processing Record 335 of Set 1 | iracoubo
# We can't find formoso do araguaia
# Processing Record 336 of Set 1 | lompoc
# Processing Record 337 of Set 1 | tazovskiy
# Processing Record 338 of Set 1 | yerbogachen
# Processing Record 339 of Set 1 | celestun
# Processing Record 340 of Set 1 | dicabisagan
# Processing Record 341 of Set 1 | cairns
# We can't find bolshiye uki
# Processing Record 342 of Set 1 | mount barker
# Processing Record 343 of Set 1 | makat
# Processing Record 344 of Set 1 | bayshore gardens
# Processing Record 345 of Set 1 | redding
# Processing Record 346 of Set 1 | katherine
# Processing Record 347 of Set 1 | makarov
# Processing Record 348 of Set 1 | palembang
# Processing Record 349 of Set 1 | bundaberg
# Processing Record 350 of Set 1 | baneh
# Processing Record 351 of Set 1 | kissidougou
# We can't find maykain
# Processing Record 352 of Set 1 | saint anthony
# Processing Record 353 of Set 1 | polunochnoye
# Processing Record 354 of Set 1 | eureka
# Processing Record 355 of Set 1 | abdulino
# Processing Record 356 of Set 1 | northam
# Processing Record 357 of Set 1 | atikokan
# We can't find gorno-chuyskiy
# We can't find marcona
# Processing Record 358 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 359 of Set 1 | pangody
# Processing Record 360 of Set 1 | diamantino
# Processing Record 361 of Set 1 | bathsheba
# Processing Record 362 of Set 1 | micheweni
# Processing Record 363 of Set 1 | porto velho
# Processing Record 364 of Set 1 | talnakh
# We can't find taburi
# Processing Record 365 of Set 1 | anderson
# Processing Record 366 of Set 1 | kaabong
# Processing Record 367 of Set 1 | kamwenge
# Processing Record 368 of Set 1 | fergus falls
# Processing Record 369 of Set 1 | tabuk
# Processing Record 370 of Set 1 | port keats
# Processing Record 371 of Set 1 | mineros
# Processing Record 372 of Set 1 | cabedelo
# Processing Record 373 of Set 1 | smithers
# Processing Record 374 of Set 1 | genhe
# Processing Record 375 of Set 1 | seoul
# Processing Record 376 of Set 1 | kahramanmaras
# Processing Record 377 of Set 1 | culaman
# Processing Record 378 of Set 1 | cururupu
# Processing Record 379 of Set 1 | hirara
# Processing Record 380 of Set 1 | charters towers
# Processing Record 381 of Set 1 | latung
# Processing Record 382 of Set 1 | mankato
# Processing Record 383 of Set 1 | rio gallegos
# Processing Record 384 of Set 1 | pronsk
# Processing Record 385 of Set 1 | cloquet
# Processing Record 386 of Set 1 | duncan
# Processing Record 387 of Set 1 | krasnoselkup
# Processing Record 388 of Set 1 | ozernovskiy
# Processing Record 389 of Set 1 | davila
# Processing Record 390 of Set 1 | dalvik
# Processing Record 391 of Set 1 | riyadh
# Processing Record 392 of Set 1 | horta
# Processing Record 393 of Set 1 | tevriz
# We can't find haibowan
# Processing Record 394 of Set 1 | alyangula
# Processing Record 395 of Set 1 | montepuez
# Processing Record 396 of Set 1 | aklavik
# Processing Record 397 of Set 1 | zaporizhzhya
# Processing Record 398 of Set 1 | aloleng
# Processing Record 399 of Set 1 | touros
# Processing Record 400 of Set 1 | bassar
# Processing Record 401 of Set 1 | pergamino
# Processing Record 402 of Set 1 | niagara falls
# Processing Record 403 of Set 1 | rabo de peixe
# Processing Record 404 of Set 1 | tukrah
# Processing Record 405 of Set 1 | bongandanga
# Processing Record 406 of Set 1 | fougamou
# Processing Record 407 of Set 1 | tieling
# Processing Record 408 of Set 1 | cidreira
# Processing Record 409 of Set 1 | fukue
# Processing Record 410 of Set 1 | dehloran
# Processing Record 411 of Set 1 | port hardy
# Processing Record 412 of Set 1 | kailua
# Processing Record 413 of Set 1 | honiara
# Processing Record 414 of Set 1 | bolobo
# Processing Record 415 of Set 1 | kyzyl
# Processing Record 416 of Set 1 | tura
# Processing Record 417 of Set 1 | boca do acre
# Processing Record 418 of Set 1 | ahipara
# Processing Record 419 of Set 1 | vanavara
# We can't find cumaribo
# Processing Record 420 of Set 1 | walvis bay
# Processing Record 421 of Set 1 | uvira
# We can't find rawannawi
# Processing Record 422 of Set 1 | ponta delgada
# Processing Record 423 of Set 1 | juneau
# Processing Record 424 of Set 1 | kidal
# Processing Record 425 of Set 1 | bontang
# Processing Record 426 of Set 1 | chanika
# Processing Record 427 of Set 1 | tanda
# Processing Record 428 of Set 1 | putina
# We can't find barawe
# We can't find bargal
# Processing Record 429 of Set 1 | denpasar
# Processing Record 430 of Set 1 | darnah
# Processing Record 431 of Set 1 | hokitika
# Processing Record 432 of Set 1 | comodoro rivadavia
# Processing Record 433 of Set 1 | ushtobe
# Processing Record 434 of Set 1 | adre
# Processing Record 435 of Set 1 | tinskoy
# We can't find rolim de moura
# Processing Record 436 of Set 1 | halifax
# Processing Record 437 of Set 1 | sao goncalo dos campos
# Processing Record 438 of Set 1 | baykit
# Processing Record 439 of Set 1 | haines junction
# Processing Record 440 of Set 1 | paragominas
# Processing Record 441 of Set 1 | tiarei
# Processing Record 442 of Set 1 | zabol
# Processing Record 443 of Set 1 | jieshi
# Processing Record 444 of Set 1 | margate
# Processing Record 445 of Set 1 | sudak
# Processing Record 446 of Set 1 | krivodanovka
# Processing Record 447 of Set 1 | altay
# Processing Record 448 of Set 1 | shibetsu
# Processing Record 449 of Set 1 | kamaishi
# We can't find qurbah
# We can't find temaraia
# Processing Record 450 of Set 1 | palmer
# Processing Record 451 of Set 1 | belmonte
# Processing Record 452 of Set 1 | merauke
# Processing Record 453 of Set 1 | bilma
# Processing Record 454 of Set 1 | taltal
# Processing Record 455 of Set 1 | ancud
# Processing Record 456 of Set 1 | strathpeffer
# Processing Record 457 of Set 1 | oxapampa
# Processing Record 458 of Set 1 | belaya gora
# Processing Record 459 of Set 1 | kiruna
# Processing Record 460 of Set 1 | biltine
# Processing Record 461 of Set 1 | katsuura
# We can't find tasbuget
# Processing Record 462 of Set 1 | christchurch
# Processing Record 463 of Set 1 | irondequoit
# Processing Record 464 of Set 1 | saint-francois
# Processing Record 465 of Set 1 | hofn
# Processing Record 466 of Set 1 | beruwala
# Processing Record 467 of Set 1 | fairbanks
# Processing Record 468 of Set 1 | ust-kulom
# Processing Record 469 of Set 1 | simao
# Processing Record 470 of Set 1 | harper
# We can't find bolungarvik
# Processing Record 471 of Set 1 | kununurra
# We can't find samusu
# Processing Record 472 of Set 1 | presidencia roque saenz pena
# Processing Record 473 of Set 1 | urusha
# We can't find tabiauea
# Processing Record 474 of Set 1 | port hawkesbury
# Processing Record 475 of Set 1 | usta muhammad
# We can't find sorvag
# Processing Record 476 of Set 1 | gualaquiza
# Processing Record 477 of Set 1 | bodden town
# Processing Record 478 of Set 1 | chicama
# Processing Record 479 of Set 1 | moss point
# Processing Record 480 of Set 1 | nabire
# Processing Record 481 of Set 1 | miyazu
# Processing Record 482 of Set 1 | harlingen
# Processing Record 483 of Set 1 | sao joao da barra
# Processing Record 484 of Set 1 | urcos
# Processing Record 485 of Set 1 | turkeve
# Processing Record 486 of Set 1 | bay roberts
# Processing Record 487 of Set 1 | bohuslav
# Processing Record 488 of Set 1 | tucurui
# Processing Record 489 of Set 1 | pirovskoye
# Processing Record 490 of Set 1 | axim
# Processing Record 491 of Set 1 | rawson
# Processing Record 492 of Set 1 | touba
# Processing Record 493 of Set 1 | novyy urengoy
# Processing Record 494 of Set 1 | hanyang
# Processing Record 495 of Set 1 | killybegs
# Processing Record 496 of Set 1 | ust-maya
# Processing Record 497 of Set 1 | lamu
# Processing Record 498 of Set 1 | sovetskaya
# Processing Record 499 of Set 1 | ercis
# Processing Record 500 of Set 1 | ladario
# Processing Record 501 of Set 1 | batemans bay
# Processing Record 502 of Set 1 | kosterevo
# Processing Record 503 of Set 1 | calbuco
# Processing Record 504 of Set 1 | kroya
# Processing Record 505 of Set 1 | nadym
# Processing Record 506 of Set 1 | tocopilla
# Processing Record 507 of Set 1 | madimba
# Processing Record 508 of Set 1 | damietta
# Processing Record 509 of Set 1 | ulaanbaatar
# Processing Record 510 of Set 1 | lavrentiya
# We can't find tidore
# Processing Record 511 of Set 1 | atambua
# Processing Record 512 of Set 1 | sabinas hidalgo
# Processing Record 513 of Set 1 | pithiviers
# Processing Record 514 of Set 1 | nishihara
# Processing Record 515 of Set 1 | loyga
# Processing Record 516 of Set 1 | peniche
# Processing Record 517 of Set 1 | butembo
# Processing Record 518 of Set 1 | la rioja
# Processing Record 519 of Set 1 | hastings
# Processing Record 520 of Set 1 | mookane
# Processing Record 521 of Set 1 | pangkalanbuun
# Processing Record 522 of Set 1 | chissamba
# Processing Record 523 of Set 1 | puerto carreno
# Processing Record 524 of Set 1 | dhanera
# Processing Record 525 of Set 1 | daro
# Processing Record 526 of Set 1 | abu samrah
# Processing Record 527 of Set 1 | yarmouth
# We can't find utiroa
# Processing Record 528 of Set 1 | lac du bonnet
# We can't find vaitupu
# Processing Record 529 of Set 1 | praia da vitoria
# Processing Record 530 of Set 1 | mecca
# Processing Record 531 of Set 1 | jaisalmer
# Processing Record 532 of Set 1 | ambulu
# Processing Record 533 of Set 1 | snezhnogorsk
# Processing Record 534 of Set 1 | patnos
# Processing Record 535 of Set 1 | kinkala
# Processing Record 536 of Set 1 | la palma
# We can't find mrirt
# We can't find qandahar
# Processing Record 537 of Set 1 | zyryanka
# Processing Record 538 of Set 1 | inndyr
# Processing Record 539 of Set 1 | kahului
# Processing Record 540 of Set 1 | biskamzha
# Processing Record 541 of Set 1 | turukhansk
# Processing Record 542 of Set 1 | pierre
# Processing Record 543 of Set 1 | sorland
# Processing Record 544 of Set 1 | berlevag
# Processing Record 545 of Set 1 | rochelle
# Processing Record 546 of Set 1 | languyan
# Processing Record 547 of Set 1 | seymchan
# Processing Record 548 of Set 1 | leninskoye
# Processing Record 549 of Set 1 | namwala
# Processing Record 550 of Set 1 | ponta do sol
# Processing Record 551 of Set 1 | roald
# Processing Record 552 of Set 1 | yar-sale
# Processing Record 553 of Set 1 | kamina
# Processing Record 554 of Set 1 | kayerkan
# Processing Record 555 of Set 1 | dharchula
# Processing Record 556 of Set 1 | miri
# Processing Record 557 of Set 1 | balaipungut
# Processing Record 558 of Set 1 | port-cartier
# Processing Record 559 of Set 1 | san jeronimo
# Processing Record 560 of Set 1 | kalikapur
# Processing Record 561 of Set 1 | sheridan
# Processing Record 562 of Set 1 | jasper
# Processing Record 563 of Set 1 | peleduy
# Processing Record 564 of Set 1 | sabang
# Processing Record 565 of Set 1 | nantucket
# Processing Record 566 of Set 1 | leningradskiy
# Processing Record 567 of Set 1 | koshurnikovo
# Processing Record 568 of Set 1 | asyut
# Processing Record 569 of Set 1 | zhangye
# Processing Record 570 of Set 1 | mancora
# Processing Record 571 of Set 1 | aksarka
# Processing Record 572 of Set 1 | aksu
# We can't find deh rawud
# Processing Record 573 of Set 1 | batagay-alyta
# Processing Record 574 of Set 1 | loxstedt
# Processing Record 575 of Set 1 | alfatar
# Processing Record 576 of Set 1 | isla vista
# Processing Record 577 of Set 1 | gulu
# Processing Record 578 of Set 1 | porto novo
# Processing Record 579 of Set 1 | methoni
# Processing Record 580 of Set 1 | mokhsogollokh
# Processing Record 581 of Set 1 | kresttsy
# Processing Record 582 of Set 1 | aripuana
# Processing Record 583 of Set 1 | thessalon
# Processing Record 584 of Set 1 | viedma
# Processing Record 585 of Set 1 | jacmel
# Processing Record 586 of Set 1 | brae
# Processing Record 587 of Set 1 | slave lake
# Processing Record 588 of Set 1 | dandong
# Processing Record 589 of Set 1 | takaka
# Processing Record 590 of Set 1 | yamada
# Processing Record 591 of Set 1 | tiznit
# Processing Record 592 of Set 1 | gayny
# Processing Record 593 of Set 1 | bathurst
# Processing Record 594 of Set 1 | mahalapye
# Processing Record 595 of Set 1 | trinidad
# Processing Record 596 of Set 1 | ciamis
# Processing Record 597 of Set 1 | rocha
# Processing Record 598 of Set 1 | pangdan
# Processing Record 599 of Set 1 | auki
# Processing Record 600 of Set 1 | manitouwadge
# We can't find kinanah
# Processing Record 601 of Set 1 | kataysk
# Processing Record 602 of Set 1 | alexandria
# Processing Record 603 of Set 1 | amahai
# Processing Record 604 of Set 1 | changji
# Processing Record 605 of Set 1 | the valley
# Processing Record 606 of Set 1 | murchison
# Processing Record 607 of Set 1 | grand gaube
# Processing Record 608 of Set 1 | dasoguz
# Processing Record 609 of Set 1 | akdepe
# Processing Record 610 of Set 1 | sungaipenuh
# Processing Record 611 of Set 1 | sapozhok
# Processing Record 612 of Set 1 | moerai
# Processing Record 613 of Set 1 | tautira
# Processing Record 614 of Set 1 | eyl
# Processing Record 615 of Set 1 | pueblo nuevo
# We can't find terenga
# We can't find ngukurr
# Processing Record 616 of Set 1 | erenhot
# Processing Record 617 of Set 1 | wilmington
# Processing Record 618 of Set 1 | troitsko-pechorsk
# Processing Record 619 of Set 1 | karauli
# Processing Record 620 of Set 1 | kapuskasing
# Processing Record 621 of Set 1 | ulladulla
# Processing Record 622 of Set 1 | maniitsoq
# Processing Record 623 of Set 1 | barda
# Processing Record 624 of Set 1 | havelock
# Processing Record 625 of Set 1 | diffa
# We can't find hendijan
# Processing Record 626 of Set 1 | opuwo
# Processing Record 627 of Set 1 | plouzane
# Processing Record 628 of Set 1 | sumbe
# Processing Record 629 of Set 1 | rutul
# Processing Record 630 of Set 1 | zhaoyuan
# Processing Record 631 of Set 1 | tabou
# Processing Record 632 of Set 1 | anuradhapura
# Processing Record 633 of Set 1 | kimbe
# Processing Record 634 of Set 1 | hobyo
# Processing Record 635 of Set 1 | columbus
# Processing Record 636 of Set 1 | colares
# Processing Record 637 of Set 1 | syracuse
# Processing Record 638 of Set 1 | kinablangan
# Processing Record 639 of Set 1 | morro da fumaca
# Processing Record 640 of Set 1 | bellegarde-sur-valserine
# Processing Record 641 of Set 1 | cam ranh
# Processing Record 642 of Set 1 | prince rupert
# Processing Record 643 of Set 1 | ust-nera
# Processing Record 644 of Set 1 | ibra
# Processing Record 645 of Set 1 | nerchinskiy zavod
# Processing Record 646 of Set 1 | los banos
# Processing Record 647 of Set 1 | rudnya
# Processing Record 648 of Set 1 | taman
# Processing Record 649 of Set 1 | bria
# Processing Record 650 of Set 1 | moramanga
# Processing Record 651 of Set 1 | vondrozo
# We can't find kamenskoye
# Processing Record 652 of Set 1 | mayo
# Processing Record 653 of Set 1 | jennings
# We can't find paradwip
# Processing Record 654 of Set 1 | nador
# Processing Record 655 of Set 1 | houlton
# Processing Record 656 of Set 1 | mwinilunga
# Processing Record 657 of Set 1 | buin
# Processing Record 658 of Set 1 | torrington
# Processing Record 659 of Set 1 | ambilobe
# Processing Record 660 of Set 1 | superior
# Processing Record 661 of Set 1 | thohoyandou
# Processing Record 662 of Set 1 | winton
# Processing Record 663 of Set 1 | salekhard
# Processing Record 664 of Set 1 | bubaque
# Processing Record 665 of Set 1 | roebourne
# Processing Record 666 of Set 1 | paoua
# Processing Record 667 of Set 1 | batagay
# Processing Record 668 of Set 1 | boden
# Processing Record 669 of Set 1 | puerto penasco
# Processing Record 670 of Set 1 | sterling
# Processing Record 671 of Set 1 | jalu
# Processing Record 672 of Set 1 | payo
# Processing Record 673 of Set 1 | dudinka
# We can't find juifang
# Processing Record 674 of Set 1 | mana
# Processing Record 675 of Set 1 | dubbo
# Processing Record 676 of Set 1 | weyburn
# Processing Record 677 of Set 1 | sur
# Processing Record 678 of Set 1 | kindu
# Processing Record 679 of Set 1 | thunder bay
# Processing Record 680 of Set 1 | stara vyzhivka
# Processing Record 681 of Set 1 | kortkeros
# Processing Record 682 of Set 1 | kabare
# Processing Record 683 of Set 1 | saint-pierre
# We can't find pousat
# Processing Record 684 of Set 1 | waw
# Processing Record 685 of Set 1 | vaitape

# %%
len(lat)
# Out:
# 685

# %%
weather_df = pd.DataFrame(
        {
            "City": city_name,
            "Lat": lat,
            "Lng": lon,
            "Max Temp": max_temp,
            "Humidity": humidity,
            "Cloudiness": clouds,
            "Wind Speed": wind,
            "Country": country
        }
)
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  685.000000  685.000000  685.000000  685.000000  685.000000  685.000000
# mean    21.174265   19.090526   46.882686   74.678832   54.547445    8.135168
# std     32.946216   89.197957   33.374312   18.258033   41.937954    5.640035
# min    -54.800000 -179.166700  -48.640000   17.000000    0.000000    0.180000
# 25%     -6.836700  -60.633300   26.010000   65.000000    1.000000    3.530000
# 50%     27.425300   26.438400   59.000000   79.000000   74.000000    6.910000
# 75%     47.816700   94.450000   73.810000   88.000000   99.000000   11.410000
# max     78.218600  178.416700   95.000000  100.000000  100.000000   33.380000

# %%
(weather_df["Humidity"] > 100).value_counts()
# Out:
# False    685
# Name: Humidity, dtype: int64

# %%
weather_df["Date"] = pd.Timestamp('2021-01-30')

# %%
weather_df.to_csv("Weather_Output.csv")

# %%
weather_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, title="City Latitude vs. Max Temperature (F) (01/30/2021)")
plt.show()

# %%
#This scatter plot shows a moderate negative correlation between a city's latitude and its max temperature for the cities sampled.

# %%
weather_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, title="City Latitude vs. Humidity (01/30/2021)")
plt.show()

# %%
#This scatter plot demonstrates there is no signficiant correlation between a city's latitude and its humidity for the cities sampled.

# %%
weather_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, title="City Latitude vs. Cloudiness (01/30/2021)")
plt.show()

# %%
#This scatter plot demonstrates there is no significant consistent correlation between a city's latitude and its cloudiness rating for the cities sampled.

# %%
weather_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, title="City Latitude vs. Wind Speed 01/30/2021")
plt.show()

# %%
#This scatter plot demonstrates there is no significant correlation between a city's latitude and its wind speed.

# %%
north_hem_df = weather_df[weather_df["Lat"]>=0]
north_hem_df.reset_index(drop=True, inplace=True)

# %%
south_hem_df = weather_df[weather_df["Lat"]<0]
south_hem_df.reset_index(drop=True, inplace=True)

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values_north = north_hem_df["Lat"]
y_values_north_temp = north_hem_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_north, y_values_north_temp)
regress_values = x_values_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values_north,y_values_north_temp)
plt.plot(x_values_north,regress_values,"r-")
plt.annotate(line_eq,(5,20),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.xlim(0, 80)
plt.ylim(0, 85)
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7491254970464449

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values_south = south_hem_df["Lat"]
y_values_south_temp = south_hem_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_south, y_values_south_temp)
regress_values = x_values_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values_south,y_values_south_temp)
plt.plot(x_values_south,regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.xlim(-55, 0)
plt.ylim(45, 100)
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.15738117250421269

# %%
#Of the cities sampled, there seems to be a higher correlation of Temperature to Latitude in the Northern Hemisphere than the Southern Hemisphere. 
#The Northern Hemisphere also leans toward a negative correlation, whereas the Southern Hemisphere leans more towards a positive correlation.

# %%
# Northern Hemisphere - Humidity vs. Latitude Linear Regression
x_values_north = north_hem_df["Lat"]
y_values_north_humidity = north_hem_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_north, y_values_north_humidity)
regress_values = x_values_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values_north,y_values_north_humidity)
plt.plot(x_values_north,regress_values,"r-")
plt.annotate(line_eq,(45,40),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.ylim(15, 100)
plt.xlim(0, 80)
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.14270113132991435

# %%
# Sourthern Hemisphere - Humidity vs. Latitude Linear Regression
x_values_south = south_hem_df["Lat"]
y_values_south = south_hem_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_south, y_values_south)
regress_values = x_values_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values_south,y_values_south)
plt.plot(x_values_south,regress_values,"r-")
plt.annotate(line_eq,(-20,40),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.ylim(10, 100)
plt.xlim(-55, 0)
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.15749797867221757

# %%
#Of the cities sampled, there seems to be no strong correlation between humidity and latitude in either the Northern or Southern Hemispheres. 
#Unlike the plots for temperature where the Northern Hemisphere clearly showed a negative correlation, both hemispheres have a tendency towards a positive correlation.

# %%
# Northern Hemisphere - Cloudiness vs. Latitude Linear Regression
x_values_north = north_hem_df["Lat"]
y_values_north = north_hem_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_north, y_values_north)
regress_values = x_values_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values_north,y_values_north)
plt.plot(x_values_north,regress_values,"r-")
plt.annotate(line_eq,(10,50),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.xlim(0, 80)
plt.ylim(0, 100)
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.07505207439796759

# %%
# Sourthern Hemisphere - Cloudiness vs. Latitude Linear Regression
x_values_south = south_hem_df["Lat"]
y_values_south = south_hem_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_south, y_values_south)
regress_values = x_values_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values_south,y_values_south)
plt.plot(x_values_south,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.ylim(0, 100)
plt.xlim(-55, 0)
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.16793306767751098

# %%
#Of the cities sampled, there seems to be no clear consistent correlation between a city's latitude and cloudiness. 
#It is interesting to note the clustering at either ends of the spectrum for both hemispheres, narrowing the results and looking at the correlation between cities in those areas could show a stronger correlation.

# %%
# Northern Hemisphere - Wind Speed vs. Latitude Linear Regression
x_values_north = north_hem_df["Lat"]
y_values_north = north_hem_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_north, y_values_north)
regress_values = x_values_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values_north,y_values_north)
plt.plot(x_values_north,regress_values,"r-")
plt.annotate(line_eq,(10,12),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.xlim(0, 80)
plt.ylim(0, 15)
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0002691011100939578

# %%
# Sourthern Hemisphere - Wind Speed vs. Latitude Linear Regression
x_values_south = south_hem_df["Lat"]
y_values_south = south_hem_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values_south, y_values_south)
regress_values = x_values_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values_south,y_values_south)
plt.plot(x_values_south,regress_values,"r-")
plt.annotate(line_eq,(-45,7),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.ylim(0, 15)
plt.xlim(-49, 0)
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.049582560748435776

# %%
#Of the cities sampled, the resulsts for wind speed vs latitude seem to have less correlation than any of the other comparisions.

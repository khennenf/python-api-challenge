# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import pprint
import json

# # Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
from api_keys import weather_api_key
print(weather_api_key)
# Out:
# 2ec28ec5c12c80c9758a8c8bb6282bec

# %%
# # List for holding lat_lngs and cities
# lat_lngs = []
# cities = []

# # Create a set of random lat and lng combinations
# lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
# lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
# lat_lngs = zip(lats, lngs)

# # Identify nearest city for each lat, lng combination
# for lat_lng in lat_lngs:
#     city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
#     # If the city is unique, then add it to a our cities list
#     if city not in cities:
#         cities.append(city)

# # Print the city count to confirm sufficient count
# len(cities)
# Out:
# 600

# %%
units = "metric"
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
weather_response = requests.get(query_url)
weather_json = weather_response.json() 
# print (f"The Weather is {weather_json}")
# print(query_url)

# %%
lat = []
lon = []
temp = []
clouds = []
wind = []
humidity = []
country=[]
city_name=[]

# %%
def  consecutive_numbers(n) :
    list=[i for i in range(len(cities))]
    return (list)
print(consecutive_numbers)
# Out:
# <function consecutive_numbers at 0x000001E5D796C950>

# %%
# for city in cities:
#     try:
#         weather_response = requests.get(query_url + city)
#         text_response = weather_response.json()
#         lat.append(text_response['coord']['lat'])
#         lon.append(text_response['coord']['lon'])
#         temp.append(text_response['main']['temp'])
#         clouds.append(text_response['clouds']['all'])
#         humidity.append(text_response['main']['humidity'])
#         wind.append(text_response['wind']['speed'])
#         country.append(text_response['sys']['country'])
#         city_name.append(text_response['name'])
#         print(f"{city} {text_response['sys']['country']}found!")
        
#     except KeyError:
#         print(f"We can't find {city}")
# Out:
# rikitea PFfound!
# paamiut GLfound!
# mar del plata ARfound!
# berlevag NOfound!
# yar-sale RUfound!
# victoria HKfound!
# ferme-neuve CAfound!
# oranjemund NAfound!
# sambava MGfound!
# maltahohe NAfound!
# opuwo NAfound!
# bluff NZfound!
# imeni poliny osipenko RUfound!
# We can't find kegayli
# belmonte BRfound!
# hilo USfound!
# vila velha BRfound!
# We can't find sentyabrskiy
# We can't find taolanaro
# We can't find buqayq
# ushuaia ARfound!
# cidreira BRfound!
# oparino RUfound!
# tual IDfound!
# barrow USfound!
# saint-pierre REfound!
# punta arenas CLfound!
# porbandar INfound!
# geraldton AUfound!
# maniitsoq GLfound!
# albany USfound!
# pekan MYfound!
# ribeira grande PTfound!
# thompson CAfound!
# otradnoye RUfound!
# port elizabeth ZAfound!
# richards bay ZAfound!
# hobart AUfound!
# cavalcante BRfound!
# iqaluit CAfound!
# port hedland AUfound!
# quatre cocos MUfound!
# egvekinot RUfound!
# saint-philippe REfound!
# We can't find attawapiskat
# arraial do cabo BRfound!
# burnie AUfound!
# avarua CKfound!
# esperance AUfound!
# salalah OMfound!
# neuquen ARfound!
# makow mazowiecki PLfound!
# semey KZfound!
# cape town ZAfound!
# tuatapere NZfound!
# mataura NZfound!
# la rioja ESfound!
# kaitangata NZfound!
# vaini TOfound!
# leningradskiy RUfound!
# We can't find illoqqortoormiut
# puerto escondido MXfound!
# katsuura JPfound!
# broome USfound!
# quibor VEfound!
# constitucion CLfound!
# liberal USfound!
# mehamn NOfound!
# port alfred ZAfound!
# cabo san lucas MXfound!
# qaanaaq GLfound!
# butaritari KIfound!
# khatanga RUfound!
# ancud CLfound!
# portmore JMfound!
# busselton AUfound!
# itacare BRfound!
# necochea ARfound!
# bastia FRfound!
# We can't find barentsburg
# paidha UGfound!
# nerchinskiy zavod RUfound!
# aylesbury GBfound!
# tuktoyaktuk CAfound!
# hermanus ZAfound!
# zonguldak TRfound!
# We can't find amderma
# kapaa USfound!
# new norfolk AUfound!
# navalmoral de la mata ESfound!
# inhambane MZfound!
# saint-georges GDfound!
# tiksi RUfound!
# oksfjord NOfound!
# saskylakh RUfound!
# college USfound!
# pacific grove USfound!
# usinsk RUfound!
# souillac MUfound!
# bayan CNfound!
# korla CNfound!
# nome USfound!
# provideniya RUfound!
# port-de-bouc FRfound!
# kodiak USfound!
# mendeleyevo RUfound!
# pacifica USfound!
# warmbad NAfound!
# georgetown MYfound!
# atuona PFfound!
# pangody RUfound!
# senador guiomard BRfound!
# rawson ARfound!
# taltal CLfound!
# lebu CLfound!
# bambous virieux MUfound!
# east london ZAfound!
# jamestown USfound!
# rio grande BRfound!
# We can't find hunza
# port lincoln AUfound!
# ishigaki JPfound!
# pisco PEfound!
# wakkanai JPfound!
# green river USfound!
# yellowknife CAfound!
# poco branco BRfound!
# port hardy CAfound!
# ratnagiri INfound!
# ntungamo UGfound!
# hastings GBfound!
# tasiilaq GLfound!
# khovu-aksy RUfound!
# taoudenni MLfound!
# We can't find tsihombe
# batemans bay AUfound!
# bubaque GWfound!
# We can't find tuggurt
# namatanai PGfound!
# hithadhoo MVfound!
# oyem GAfound!
# saint anthony USfound!
# mabaruma GYfound!
# chokurdakh RUfound!
# bethel USfound!
# We can't find kamenskoye
# severo-kurilsk RUfound!
# We can't find uroteppa
# vardo NOfound!
# adrar MRfound!
# We can't find bandar penggaram
# We can't find himora
# san patricio USfound!
# kahului USfound!
# ixtapa MXfound!
# We can't find grand river south east
# villazon BOfound!
# juegang CNfound!
# upernavik GLfound!
# prince rupert CAfound!
# natal BRfound!
# washington USfound!
# talavera de la reina ESfound!
# bandarbeyla SOfound!
# faanui PFfound!
# saint george USfound!
# qaqortoq GLfound!
# nanortalik GLfound!
# rocky mountain house CAfound!
# balkhash KZfound!
# kruisfontein ZAfound!
# batagay RUfound!
# sikonge TZfound!
# kaseda JPfound!
# oktyabrskiy RUfound!
# trelew ARfound!
# bressuire FRfound!
# castro BRfound!
# darhan MNfound!
# We can't find belushya guba
# rundu NAfound!
# nishihara JPfound!
# hualmay PEfound!
# manggar IDfound!
# lasa ITfound!
# calvinia ZAfound!
# poum NCfound!
# bengkulu IDfound!
# emerald AUfound!
# We can't find grimari
# puerto ayora ECfound!
# gabu GWfound!
# pembroke CAfound!
# luderitz NAfound!
# mazatan MXfound!
# paracatu BRfound!
# zacualtipan MXfound!
# parabel RUfound!
# tilichiki RUfound!
# sola VUfound!
# regeneracao BRfound!
# asau ROfound!
# flinders AUfound!
# fort-shevchenko KZfound!
# san rafael ARfound!
# mogadishu SOfound!
# mahebourg MUfound!
# torbay CAfound!
# mattru SLfound!
# sorland NOfound!
# gat ILfound!
# zhigansk RUfound!
# bonfim BRfound!
# We can't find mutsamudu
# ilulissat GLfound!
# tara RUfound!
# We can't find louisbourg
# hopkinsville USfound!
# We can't find kuche
# virginia beach USfound!
# aykhal RUfound!
# narsaq GLfound!
# yekepa LRfound!
# jiangyou CNfound!
# karratha AUfound!
# tomarovka RUfound!
# nemuro JPfound!
# luanda AOfound!
# haines junction CAfound!
# kavieng PGfound!
# nikolskoye RUfound!
# konce MKfound!
# mogocha RUfound!
# phan thiet VNfound!
# clyde river CAfound!
# We can't find arkhangelos
# ponta do sol PTfound!
# fairbanks USfound!
# mincivan AZfound!
# mount isa AUfound!
# urumqi CNfound!
# datong CNfound!
# santiago de cao PEfound!
# balykshi KZfound!
# hambantota LKfound!
# arraias BRfound!
# puerto colombia COfound!
# yeniseysk RUfound!
# fairmont USfound!
# luau AOfound!
# ostrovnoy RUfound!
# vestmannaeyjar ISfound!
# sungaipenuh IDfound!
# biggar GBfound!
# saldanha ZAfound!
# poya NCfound!
# solnechnyy RUfound!
# crotone ITfound!
# lagoa PTfound!
# We can't find vaitupu
# sakakah SAfound!
# leshukonskoye RUfound!
# port blair INfound!
# innisfail AUfound!
# malko tarnovo BGfound!
# hasaki JPfound!
# son la VNfound!
# henties bay NAfound!
# longyearbyen SJfound!
# black forest USfound!
# tocopilla CLfound!
# coruripe BRfound!
# shinpokh PKfound!
# rumoi JPfound!
# yulara AUfound!
# suoyarvi RUfound!
# deputatskiy RUfound!
# itoman JPfound!
# We can't find dieppe bay
# dikson RUfound!
# faya SAfound!
# alcaudete ESfound!
# alamosa USfound!
# puerto madryn ARfound!
# ullapool GBfound!
# urambo TZfound!
# axim GHfound!
# caravelas BRfound!
# fortuna USfound!
# samarai PGfound!
# sangar RUfound!
# margate GBfound!
# ha tinh VNfound!
# altar MXfound!
# ulaangom MNfound!
# eyemouth GBfound!
# santa cruz BOfound!
# laufen DEfound!
# We can't find krivopolyanye
# biltine TDfound!
# luchegorsk RUfound!
# dingle PHfound!
# We can't find yeehaw junction
# kununurra AUfound!
# shetpe KZfound!
# bykovo RUfound!
# tecpan GTfound!
# padang IDfound!
# voskresenskoye RUfound!
# kilindoni TZfound!
# kavaratti INfound!
# labuhan IDfound!
# We can't find samusu
# mossendjo CGfound!
# jalu LYfound!
# bemidji USfound!
# antequera ESfound!
# plettenberg bay ZAfound!
# la primavera COfound!
# kahramanmaras TRfound!
# pevek RUfound!
# talnakh RUfound!
# neckarsulm DEfound!
# We can't find saleaula
# clacton-on-sea GBfound!
# kismayo SOfound!
# biak IDfound!
# humaita BRfound!
# We can't find mrirt
# We can't find tumannyy
# paramirim BRfound!
# komsomolskiy UZfound!
# terrace bay CAfound!
# tazovskiy RUfound!
# buala SBfound!
# te anau NZfound!
# sao filipe CVfound!
# townsville AUfound!
# We can't find warqla
# macau MOfound!
# arman RUfound!
# sisimiut GLfound!
# isangel VUfound!
# boca do acre BRfound!
# muros ESfound!
# We can't find artyk
# ahipara NZfound!
# tibiri NEfound!
# beeville USfound!
# great yarmouth GBfound!
# beringovskiy RUfound!
# bredasdorp ZAfound!
# namibe AOfound!
# alugan PHfound!
# muri INfound!
# harwich GBfound!
# west bay KYfound!
# rivadavia ARfound!
# simao CNfound!
# pemba MZfound!
# mucurapo TTfound!
# rimbey CAfound!
# vostok RUfound!
# kralendijk BQfound!
# nuuk GLfound!
# martapura IDfound!
# kamenka RUfound!
# dania beach USfound!
# srednekolymsk RUfound!
# roma USfound!
# corinth GRfound!
# carnarvon AUfound!
# ustye RUfound!
# chazuta PEfound!
# sterling USfound!
# wladyslawowo PLfound!
# homer USfound!
# rebra ROfound!
# praia da vitoria PTfound!
# balclutha NZfound!
# half moon bay USfound!
# akcakoca TRfound!
# bagaces CRfound!
# manati PRfound!
# albert lea USfound!
# We can't find nabul
# tshikapa CDfound!
# meulaboh IDfound!
# We can't find mergui
# cherskiy RUfound!
# trairi BRfound!
# rolla USfound!
# parkes AUfound!
# oussouye SNfound!
# comodoro rivadavia ARfound!
# normandin CAfound!
# We can't find bargal
# ibimirim BRfound!
# We can't find viligili
# puro PHfound!
# We can't find mys shmidta
# san quintin MXfound!
# svetlaya RUfound!
# garissa KEfound!
# ayaviri PEfound!
# serro BRfound!
# eenhana NAfound!
# fukue JPfound!
# cockburn town TCfound!
# kearney USfound!
# ewa beach USfound!
# We can't find utiroa
# We can't find ondorhaan
# mahibadhoo MVfound!
# savannah bight HNfound!
# pechora RUfound!
# lufilufi WSfound!
# We can't find marcona
# pangnirtung CAfound!
# nhulunbuy AUfound!
# tautira PFfound!
# tiznit MAfound!
# wewak PGfound!
# vao NCfound!
# zhanakorgan KZfound!
# bonthe SLfound!
# gordeyevka RUfound!
# aromashevo RUfound!
# kangaatsiaq GLfound!
# santa isabel BRfound!
# atar MRfound!
# sistranda NOfound!
# ayna PEfound!
# havelock USfound!
# madimba TZfound!
# boddam GBfound!
# arroyo ESfound!
# We can't find inderborskiy
# consett GBfound!
# sechura PEfound!
# carutapera BRfound!
# kushima JPfound!
# prainha BRfound!
# gamba GAfound!
# sotnikovskoye RUfound!
# veraval INfound!
# bria CFfound!
# robe AUfound!
# bilma NEfound!
# zaoyang CNfound!
# northam GBfound!
# ust-ilimsk RUfound!
# kokstad ZAfound!
# We can't find khonuu
# hamilton USfound!
# fairhope USfound!
# la palma USfound!
# emba KZfound!
# We can't find halalo
# benoy TDfound!
# garowe SOfound!
# omidiyeh IRfound!
# hami CNfound!
# husavik ISfound!
# fomboni KMfound!
# burley USfound!
# mecca SAfound!
# quelimane MZfound!
# cayenne GFfound!
# akdepe TMfound!
# along INfound!
# mazagao BRfound!
# nyurba RUfound!
# urussanga BRfound!
# sosnogorsk RUfound!
# bestobe KZfound!
# esmeraldas BRfound!
# takab IRfound!
# brunico ITfound!
# chicama PEfound!
# shingu JPfound!
# alofi NUfound!
# mahenge TZfound!
# bartow USfound!
# mae ramat THfound!
# We can't find galiwinku
# lewiston USfound!
# chuy UYfound!
# krasnokamensk RUfound!
# tateyama JPfound!
# huntsville USfound!
# koping SEfound!
# luis correia BRfound!
# russkaya polyana UAfound!
# newport GBfound!
# vigrestad NOfound!
# tevaitoa PFfound!
# airai TLfound!
# kungurtug RUfound!
# touros BRfound!
# snezhnogorsk RUfound!
# pangai TOfound!
# baghdad IQfound!
# hirado JPfound!
# sao felix do xingu BRfound!
# vila franca do campo PTfound!
# port macquarie AUfound!
# tierranueva MXfound!
# shizilu CNfound!
# vaitape PFfound!
# whitehorse CAfound!
# We can't find nizhneyansk
# santa ana USfound!
# pierre USfound!
# hohhot CNfound!
# popondetta PGfound!
# guerrero negro MXfound!
# We can't find ye
# wanning CNfound!
# borogontsy RUfound!
# floro NOfound!
# chongwe ZMfound!
# kroya IDfound!
# lodwar KEfound!
# chifeng CNfound!
# We can't find gurgan
# mount gambier AUfound!
# maryborough AUfound!
# kurilsk RUfound!
# We can't find palabuhanratu
# formosa ARfound!
# dunedin NZfound!
# carballo ESfound!
# norman wells CAfound!
# kamaishi JPfound!
# aklavik CAfound!
# celestun MXfound!
# san andres COfound!
# mugur-aksy RUfound!
# sawakin SDfound!
# khani GEfound!
# We can't find fort saint john
# gurupa BRfound!
# elbistan TRfound!
# costesti ROfound!
# awjilah LYfound!
# We can't find nylstroom
# saint-augustin CAfound!
# kloulklubed PWfound!
# nikolsk RUfound!
# pitangui BRfound!
# qiongshan CNfound!
# bilibino RUfound!
# vredendal ZAfound!
# bontang IDfound!
# anadyr RUfound!
# zverinogolovskoye RUfound!
# gutierrez COfound!
# ngunguru NZfound!
# lorengau PGfound!
# walvis bay NAfound!
# porto novo BJfound!
# villacarrillo ESfound!
# We can't find falealupo
# loa janan IDfound!
# forio ITfound!
# vanimo PGfound!
# russell USfound!
# We can't find kawana waters
# boa vista BRfound!
# morant bay JMfound!
# ouadda CFfound!
# cabedelo BRfound!
# kaduqli SDfound!
# katima mulilo NAfound!
# sitka USfound!
# tierra blanca HNfound!
# dalby AUfound!
# scarborough GBfound!
# bar harbor USfound!
# otane NZfound!
# praya CVfound!
# sioux lookout CAfound!
# belaya gora RUfound!
# tabasalu EEfound!
# mongoumba CFfound!
# tazmalt DZfound!
# maceio BRfound!
# bonavista CAfound!
# eruwa NGfound!
# chimbote PEfound!
# andenes NOfound!
# bathurst AUfound!
# tukrah LYfound!
# uruacu BRfound!
# lokosovo RUfound!
# olafsvik ISfound!
# acari PEfound!
# grand gaube MUfound!
# stromness GBfound!

# %%
len(city_name)
# Out:
# 548

# %%
weather_df = pd.DataFrame(
        {
            "City": city_name,
            "Lat": lat,
            "Lng": lon,
            "Temp": temp,
            "Humidity": humidity,
            "Cloudiness": clouds,
            "Wind Speed": wind,
            "Country": country
        }
)
weather_df
# Out:
#               City      Lat       Lng   Temp  Humidity  Cloudiness  \
# 0          Rikitea -23.1203 -134.9692  26.69        67          48
# 1          Paamiut  61.9940  -49.6678   2.27        76         100
# 2    Mar del Plata -38.0023  -57.5575  22.02        88          90
# 3         Berlevåg  70.8578   29.0864  -4.92        91         100
# 4         Yar-Sale  66.8333   70.8333 -34.62        84          98
# ..             ...      ...       ...    ...       ...         ...
# 543       Lokosovo  61.1333   74.8167 -25.28        89          68
# 544       Olafsvik  64.8945  -23.7142  -1.00        88          96
# 545          Acarí -15.4311  -74.6158  22.31        63          47
# 546    Grand Gaube -20.0064   57.6608  25.56        78          17
# 547      Stromness  58.9650   -3.2960   3.94        73          67
#
#      Wind Speed Country
# 0          3.34      PF
# 1          4.09      GL
# 2          2.57      AR
# 3         11.48      NO
# 4          4.42      RU
# ..          ...     ...
# 543        3.26      RU
# 544        1.74      IS
# 545        1.06      PE
# 546        1.79      MU
# 547        9.52      GB
#
# [548 rows x 8 columns]

# %%
weather_df.to_csv("Weather_Output.csv")

# %%
weather_df.describe()
# Out:
#               Lat         Lng        Temp    Humidity  Cloudiness  Wind Speed
# count  548.000000  548.000000  548.000000  548.000000  548.000000  548.000000
# mean    19.705359   14.752194    8.411004   75.888686   56.852190    4.000511
# std     34.099769   90.293829   18.091325   17.403072   41.448566    2.993980
# min    -54.800000 -179.166700  -45.990000    9.000000    0.000000    0.190000
# 25%     -9.699350  -63.057275   -2.852500   67.000000    6.000000    1.740000
# 50%     22.243050   17.531000   13.425000   79.000000   72.000000    3.335000
# 75%     48.828125   93.487500   23.282500   88.000000  100.000000    5.490000
# max     78.218600  179.316700   36.000000  100.000000  100.000000   18.230000

# %%
(weather_df["Humidity"] > 100).value_counts()
# Out:
# False    548
# Name: Humidity, dtype: int64

# %%
print(weather_df["Humidity"].max())
# Out:
# 100

# %%
weather_df.loc[:, 'Date'] = pd.to_datetime(weather_df.Date)
weather_df["Date"] = pd.Timestamp('2021-01-28')

# %%
# Out:
#               City      Lat       Lng   Temp  Humidity  Cloudiness  \
# 0          Rikitea -23.1203 -134.9692  26.69        67          48
# 1          Paamiut  61.9940  -49.6678   2.27        76         100
# 2    Mar del Plata -38.0023  -57.5575  22.02        88          90
# 3         Berlevåg  70.8578   29.0864  -4.92        91         100
# 4         Yar-Sale  66.8333   70.8333 -34.62        84          98
# ..             ...      ...       ...    ...       ...         ...
# 543       Lokosovo  61.1333   74.8167 -25.28        89          68
# 544       Olafsvik  64.8945  -23.7142  -1.00        88          96
# 545          Acarí -15.4311  -74.6158  22.31        63          47
# 546    Grand Gaube -20.0064   57.6608  25.56        78          17
# 547      Stromness  58.9650   -3.2960   3.94        73          67
#
#      Wind Speed Country       Date
# 0          3.34      PF 2021-01-28
# 1          4.09      GL 2021-01-28
# 2          2.57      AR 2021-01-28
# 3         11.48      NO 2021-01-28
# 4          4.42      RU 2021-01-28
# ..          ...     ...        ...
# 543        3.26      RU 2021-01-28
# 544        1.74      IS 2021-01-28
# 545        1.06      PE 2021-01-28
# 546        1.79      MU 2021-01-28
# 547        9.52      GB 2021-01-28
#
# [548 rows x 9 columns]
